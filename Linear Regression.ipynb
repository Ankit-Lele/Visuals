# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

def encode_labels(df):
    le = preprocessing.LabelEncoder()
    for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
    return df


training_df = pd.read_csv('loans_full_schema.csv')
test_df = pd.read_csv('loans_full_schema.csv')

int_rate = training_df["interest_rate"]
training_df = training_df.drop('interest_rate', axis=1)


training_df = encode_labels(training_df)
test_df = encode_labels(test_df)

model = LinearRegression().fit(training_df, int_rate)

res = model.predict(test_df)
predicted_df = pd.Series(res)

r_square = model.score(training_df, int_rate)
print("Score: " + str(r_square))
predicted_df.to_csv("predicted_rate.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 23>()
#      20 training_df = encode_labels(training_df)
#      21 test_df = encode_labels(test_df)
# ---> 23 model = LinearRegression().fit(training_df, int_rate)
#      25 res = model.predict(test_df)
#      26 predicted_df = pd.Series(res)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

def encode_labels(df):
    le = preprocessing.LabelEncoder()
    for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
    return df


training_df = pd.read_csv('loans_full_schema.csv')
test_df = pd.read_csv('loans_full_schema.csv')

int_rate = training_df["interest_rate"]
training_df = training_df.drop('interest_rate', axis=1)


training_df = encode_labels(training_df)
test_df = encode_labels(test_df)

model = LinearRegression().fit(training_df, int_rate)

res = model.predict(test_df)
predicted_df = pd.Series(res)

r_square = model.score(training_df, int_rate)
print("Score: " + str(r_square))
predicted_df.to_csv("predicted_interest_rate.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 23>()
#      20 training_df = encode_labels(training_df)
#      21 test_df = encode_labels(test_df)
# ---> 23 model = LinearRegression().fit(training_df, int_rate)
#      25 res = model.predict(test_df)
#      26 predicted_df = pd.Series(res)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# ...

# %%
training_df.isnull().sum()
# Out:
# emp_title                              0
# emp_length                           817
# state                                  0
# homeownership                          0
# annual_income                          0
# verified_income                        0
# debt_to_income                        24
# annual_income_joint                 8505
# verification_income_joint              0
# debt_to_income_joint                8505
# delinq_2y                              0
# months_since_last_delinq            5658
# earliest_credit_line                   0
# inquiries_last_12m                     0
# total_credit_lines                     0
# open_credit_lines                      0
# total_credit_limit                     0
# total_credit_utilized                  0
# num_collections_last_12m               0
# num_historical_failed_to_pay           0
# months_since_90d_late               7715
# current_accounts_delinq                0
# total_collection_amount_ever           0
# ...

# %%
training_df.drop('annual_income_joint', axis=1, inplace=True)

# %%
training_df.drop('verification_income_joint', axis=1, inplace=True)
training_df.drop('debt_to_income_joint', axis=1, inplace=True)
training_df.drop('months_since_last_delinq', axis=1, inplace=True)
training_df.drop('months_since_90d_late', axis=1, inplace=True)
training_df.drop('months_since_last_credit_inquiry', axis=1, inplace=True)
training_df.drop('num_accounts_120d_past_due', axis=1, inplace=True)
training_df['emp_title']=training_df['emp_title'].fillna(dataset['emp_title'].mode().values[0] )
training_df['emp_length']=training_df['emp_length'].fillna(dataset['emp_length'].mode().values[0] )
training_df['debt_to_income']=training_df['debt_to_income'].fillna(dataset['debt_to_income'].mode().values[0] )
training_df.drop('emp_title', axis=1, inplace=True)
training_df.drop('homeownership', axis=1, inplace=True)
training_df.drop('loan_purpose', axis=1, inplace=True)
training_df.drop('application_type', axis=1, inplace=True)
training_df.drop('verified_income', axis=1, inplace=True)
training_df.drop('state', axis=1, inplace=True)
training_df.drop('grade', axis=1, inplace=True)
training_df.drop('sub_grade', axis=1, inplace=True)
training_df.drop('issue_month', axis=1, inplace=True)
training_df.drop('loan_status', axis=1, inplace=True)
training_df.drop('initial_listing_status', axis=1, inplace=True)
training_df.drop('disbursement_method', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 training_df.drop('verification_income_joint', axis=1, inplace=True)
#       2 training_df.drop('debt_to_income_joint', axis=1, inplace=True)
#       3 training_df.drop('months_since_last_delinq', axis=1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
training_df['emp_title']=training_df['emp_title'].fillna(training_df['emp_title'].mode().values[0] )
training_df['emp_length']=training_df['emp_length'].fillna(training_df['emp_length'].mode().values[0] )
training_df['debt_to_income']=training_df['debt_to_income'].fillna(training_df['debt_to_income'].mode().values[0] )

# %%
training_df.isnull().sum()
# Out:
# emp_title                       0
# emp_length                      0
# state                           0
# homeownership                   0
# annual_income                   0
# verified_income                 0
# debt_to_income                  0
# delinq_2y                       0
# earliest_credit_line            0
# inquiries_last_12m              0
# total_credit_lines              0
# open_credit_lines               0
# total_credit_limit              0
# total_credit_utilized           0
# num_collections_last_12m        0
# num_historical_failed_to_pay    0
# current_accounts_delinq         0
# total_collection_amount_ever    0
# current_installment_accounts    0
# accounts_opened_24m             0
# num_satisfactory_accounts       0
# num_accounts_30d_past_due       0
# num_active_debit_accounts       0
# total_debit_limit               0
# num_total_cc_accounts           0
# num_open_cc_accounts            0
# num_cc_carrying_balance         0
# ...

# %% [raw]
# test_df.drop('verification_income_joint', axis=1, inplace=True)
# test_df.drop('debt_to_income_joint', axis=1, inplace=True)
# test_df.drop('months_since_last_delinq', axis=1, inplace=True)
# test_df.drop('months_since_90d_late', axis=1, inplace=True)
# test_df.drop('months_since_last_credit_inquiry', axis=1, inplace=True)
# test_df.drop('num_accounts_120d_past_due', axis=1, inplace=True)
# test_df['emp_title']=test_df['emp_title'].fillna(test_df['emp_title'].mode().values[0] )
# test_df['emp_length']=test_df['emp_length'].fillna(test_df['emp_length'].mode().values[0] )
# test_df['debt_to_income']=test_df['debt_to_income'].fillna(test_df['debt_to_income'].mode().values[0] )
# test_df.drop('emp_title', axis=1, inplace=True)
# test_df.drop('homeownership', axis=1, inplace=True)
# test_df.drop('loan_purpose', axis=1, inplace=True)
# test_df.drop('application_type', axis=1, inplace=True)
# test_df.drop('verified_income', axis=1, inplace=True)
# test_df.drop('state', axis=1, inplace=True)
# test_df.drop('grade', axis=1, inplace=True)
# test_df.drop('sub_grade', axis=1, inplace=True)
# test_df.drop('issue_month', axis=1, inplace=True)
# test_df.drop('loan_status', axis=1, inplace=True)
# test_df.drop('initial_listing_status', axis=1, inplace=True)
# test_df.drop('disbursement_method', axis=1, inplace=True)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

def encode_labels(df):
    le = preprocessing.LabelEncoder()
    for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
    return df


training_df = pd.read_csv('loans_full_schema.csv')
test_df = pd.read_csv('loans_full_schema.csv')

int_rate = training_df["interest_rate"]
training_df = training_df.drop('interest_rate', axis=1)


training_df = encode_labels(training_df)
test_df = encode_labels(test_df)

model = LinearRegression().fit(training_df, int_rate)

res = model.predict(test_df)
predicted_df = pd.Series(res)

r_square = model.score(training_df, int_rate)
print("Score: " + str(r_square))
predicted_df.to_csv("predicted_rate.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 23>()
#      20 training_df = encode_labels(training_df)
#      21 test_df = encode_labels(test_df)
# ---> 23 model = LinearRegression().fit(training_df, int_rate)
#      25 res = model.predict(test_df)
#      26 predicted_df = pd.Series(res)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   emp_title                         10000 non-null  int32
#  1   emp_length                        9183 non-null   float64
#  2   state                             10000 non-null  int32
#  3   homeownership                     10000 non-null  int32
#  4   annual_income                     10000 non-null  float64
#  5   verified_income                   10000 non-null  int32
#  6   debt_to_income                    9976 non-null   float64
#  7   annual_income_joint               1495 non-null   float64
#  8   verification_income_joint         10000 non-null  int32
#  9   debt_to_income_joint              1495 non-null   float64
#  10  delinq_2y                         10000 non-null  int64
# ...

# %%
test_df.drop('verification_income_joint', axis=1, inplace=True)
test_df.drop('debt_to_income_joint', axis=1, inplace=True)
test_df.drop('months_since_last_delinq', axis=1, inplace=True)
test_df.drop('months_since_90d_late', axis=1, inplace=True)
test_df.drop('months_since_last_credit_inquiry', axis=1, inplace=True)
test_df.drop('num_accounts_120d_past_due', axis=1, inplace=True)
test_df['emp_title']=test_df['emp_title'].fillna(test_df['emp_title'].mode().values[0] )
test_df['emp_length']=test_df['emp_length'].fillna(test_df['emp_length'].mode().values[0] )
test_df['debt_to_income']=test_df['debt_to_income'].fillna(test_df['debt_to_income'].mode().values[0] )
test_df.drop('emp_title', axis=1, inplace=True)
test_df.drop('homeownership', axis=1, inplace=True)
test_df.drop('loan_purpose', axis=1, inplace=True)
test_df.drop('application_type', axis=1, inplace=True)
test_df.drop('verified_income', axis=1, inplace=True)
test_df.drop('state', axis=1, inplace=True)
test_df.drop('grade', axis=1, inplace=True)
test_df.drop('sub_grade', axis=1, inplace=True)
test_df.drop('issue_month', axis=1, inplace=True)
test_df.drop('loan_status', axis=1, inplace=True)
test_df.drop('initial_listing_status', axis=1, inplace=True)
test_df.drop('disbursement_method', axis=1, inplace=True)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   emp_length                    10000 non-null  float64
#  1   annual_income                 10000 non-null  float64
#  2   debt_to_income                10000 non-null  float64
#  3   annual_income_joint           1495 non-null   float64
#  4   delinq_2y                     10000 non-null  int64
#  5   earliest_credit_line          10000 non-null  int64
#  6   inquiries_last_12m            10000 non-null  int64
#  7   total_credit_lines            10000 non-null  int64
#  8   open_credit_lines             10000 non-null  int64
#  9   total_credit_limit            10000 non-null  int64
#  10  total_credit_utilized         10000 non-null  int64
#  11  num_collections_last_12m      10000 non-null  int64
# ...

# %%
training_df['emp_title']=training_df['emp_title'].fillna(training_df['emp_title'].mode().values[0] )
training_df['emp_length']=training_df['emp_length'].fillna(training_df['emp_length'].mode().values[0] )
training_df['debt_to_income']=training_df['debt_to_income'].fillna(training_df['debt_to_income'].mode().values[0] )
training_df.drop('emp_title', axis=1, inplace=True)
training_df.drop('homeownership', axis=1, inplace=True)
training_df.drop('loan_purpose', axis=1, inplace=True)
training_df.drop('application_type', axis=1, inplace=True)
training_df.drop('verified_income', axis=1, inplace=True)
training_df.drop('state', axis=1, inplace=True)
training_df.drop('grade', axis=1, inplace=True)
training_df.drop('sub_grade', axis=1, inplace=True)
training_df.drop('issue_month', axis=1, inplace=True)
training_df.drop('loan_status', axis=1, inplace=True)
training_df.drop('initial_listing_status', axis=1, inplace=True)
training_df.drop('disbursement_method', axis=1, inplace=True)

# %%
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   emp_length                    10000 non-null  float64
#  1   annual_income                 10000 non-null  float64
#  2   debt_to_income                10000 non-null  float64
#  3   annual_income_joint           1495 non-null   float64
#  4   delinq_2y                     10000 non-null  int64
#  5   earliest_credit_line          10000 non-null  int64
#  6   inquiries_last_12m            10000 non-null  int64
#  7   total_credit_lines            10000 non-null  int64
#  8   open_credit_lines             10000 non-null  int64
#  9   total_credit_limit            10000 non-null  int64
#  10  total_credit_utilized         10000 non-null  int64
#  11  num_collections_last_12m      10000 non-null  int64
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

def encode_labels(df):
    le = preprocessing.LabelEncoder()
    for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
    return df


training_df = pd.read_csv('loans_full_schema.csv')
test_df = pd.read_csv('loans_full_schema.csv')

int_rate = training_df["interest_rate"]
training_df = training_df.drop('interest_rate', axis=1)


training_df = encode_labels(training_df)
test_df = encode_labels(test_df)

model = LinearRegression().fit(training_df, int_rate)

res = model.predict(test_df)
predicted_df = pd.Series(res)

r_square = model.score(training_df, int_rate)
print("Score: " + str(r_square))
predicted_df.to_csv("predicted_interest_rate.csv", index=False)
